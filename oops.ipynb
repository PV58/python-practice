# %% [markdown]
# # oops

# %%
import turtle

# %%
turtle = turtle.Turtle()

# %%
from turtle import Turtle, Screen
timmy = Turtle() 
print(timmy)

# %%
timmy = Turtle()
print(timmy)
timmy.shape('turtle')
timmy.color('blue')
my_screen = Screen()
print(my_screen.canvheight)
my_screen.exitonclick
# Out:
# ...
# 300
# <bound method _Screen.exitonclick of <turtle._Screen object at 0x10ad2ee40>>
