# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"], index=["X","Y","Z"])

# %%
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9>

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# # LOADING DATASET

# %%
df = pd.read_csv("dataset/Warehouse_and_Retail_Sales.csv")

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
# 307644  2020      9                                NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                           BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.head()
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 307645 entries, 0 to 307644
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307645 non-null  int64
#  1   MONTH             307645 non-null  int64
#  2   SUPPLIER          307478 non-null  str
#  3   ITEM CODE         307645 non-null  str
#  4   ITEM DESCRIPTION  307645 non-null  str
#  5   ITEM TYPE         307644 non-null  str
#  6   RETAIL SALES      307642 non-null  float64
#  7   RETAIL TRANSFERS  307645 non-null  float64
#  8   WAREHOUSE SALES   307645 non-null  float64
# dtypes: float64(3), int64(2), str(4)
# memory usage: 21.1 MB

# %%
display(df)
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
# 307644  2020      9                                NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                           BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.tail()
# Out:
#         YEAR  MONTH                     SUPPLIER ITEM CODE  \
# 307640  2020      9                  LEGENDS LTD     99753
# 307641  2020      9           ANHEUSER BUSCH INC      9997
# 307642  2020      9  COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9      BOSTON BEER CORPORATION     99990
# 307644  2020      9                          NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 307640         DUTCHESS DE BOURGOGNE NR - 750ML      BEER          0.00
# 307641                  HOEGAARDEN 4/6NR - 12OZ      BEER         66.12
# 307642  DOMINION OAK BARREL STOUT 4/6 NR - 12OZ      BEER          2.25
# 307643         SAM ADAMS SUMMER VARIETY 12PK NR      BEER         20.50
# 307644                              WINE CREDIT       REF          0.00
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 307640               0.0             5.00
# 307641              37.0           240.75
# 307642               0.0             0.00
# ...

# %%
df.head(10)
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
# 5  2020      1            KYSELA PERE ET FILS LTD    100641
# 6  2020      1           SANTA MARGHERITA USA INC    100749
# 7  2020      1   BROWN-FORMAN BEVERAGES WORLDWIDE      1008
# 8  2020      1                 JIM BEAM BRANDS CO     10103
# 9  2020      1          INTERNATIONAL CELLARS LLC    101117
#
#                                     ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                                BOOTLEG RED - 750ML      WINE          0.00
# 1                          MOMENT DE PLAISIR - 750ML      WINE          0.00
# ...

# %%
df.sample(10)
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 17221   2020      7  REPUBLIC NATIONAL DISTRIBUTING CO    348638
# 30513   2020      3                       HEINEKEN USA      4553
# 286461  2019     11                ELITE WINES IMPORTS    305111
# 110096  2017     11          LANTERNA DISTRIBUTORS INC    363618
# 192619  2019      3    OPICI FAMILY DISTRIBUTING OF MD     72356
# 242883  2019      7            BOSTON BEER CORPORATION     70604
# 234421  2019      7                GRAPES OF SPAIN INC    234652
# 171293  2019      2          MONSIEUR TOUTON SELECTION    232342
# 91150   2017     10           DIAGEO NORTH AMERICA INC     27618
# 235091  2019      7            KYSELA PERE ET FILS LTD     24994
#
#                                          ITEM DESCRIPTION ITEM TYPE  \
# 17221                                 IMAGERY CAB - 750ML      WINE
# 30513                           RED STRIPE 2/12 NR - 12OZ      BEER
# ...

# %%
##df.loc[#ROW, #COLUMNS] CONDINTIONAL SELECTION
df.loc[df["ITEM TYPE"]!= "WINE"]
# Out:
#         YEAR  MONTH                          SUPPLIER ITEM CODE  \
# 2       2020      1           RELIABLE CHURCHILL LLLP      1001
# 7       2020      1  BROWN-FORMAN BEVERAGES WORLDWIDE      1008
# 8       2020      1                JIM BEAM BRANDS CO     10103
# 10      2020      1      HEAVEN HILL DISTILLERIES INC     10120
# 11      2020      1             BACCHUS IMPORTERS LTD     10123
# ...      ...    ...                               ...       ...
# 307640  2020      9                       LEGENDS LTD     99753
# 307641  2020      9                ANHEUSER BUSCH INC      9997
# 307642  2020      9       COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9           BOSTON BEER CORPORATION     99990
# 307644  2020      9                               NaN        WC
#
#                                          ITEM DESCRIPTION ITEM TYPE  \
# 2                     S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER
# ...

# %%
df.loc[:, ["ITEM CODE","ITEM TYPE"]] #SELECTING SLICE COLUMNS USING LOC
# Out:
#        ITEM CODE ITEM TYPE
# 0         100009      WINE
# 1         100024      WINE
# 2           1001      BEER
# 3         100145      WINE
# 4         100293      WINE
# ...          ...       ...
# 307640     99753      BEER
# 307641      9997      BEER
# 307642     99970      BEER
# 307643     99990      BEER
# 307644        WC       REF
#
# [307645 rows x 2 columns]

# %%
#SELECTING BOTH ROW AND COLUMN
df.loc[df['YEAR']>2012, "MONTH": "RETAIL SALES"]
# Out:
#         MONTH                           SUPPLIER ITEM CODE  \
# 0           1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1           1                          PWSWN INC    100024
# 2           1            RELIABLE CHURCHILL LLLP      1001
# 3           1          LANTERNA DISTRIBUTORS INC    100145
# 4           1               DIONYSOS IMPORTS INC    100293
# ...       ...                                ...       ...
# 307640      9                        LEGENDS LTD     99753
# 307641      9                 ANHEUSER BUSCH INC      9997
# 307642      9        COASTAL BREWING COMPANY LLC     99970
# 307643      9            BOSTON BEER CORPORATION     99990
# 307644      9                                NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES
# 0                           BOOTLEG RED - 750ML      WINE          0.00
# 1                     MOMENT DE PLAISIR - 750ML      WINE          0.00
# ...

# %%
df.iloc[:,[0,4]] #it uses integer like form 0 to 4 = 0,1,2,3 whereas loc 0,4 0 and 4 only
# Out:
#         YEAR                         ITEM DESCRIPTION
# 0       2020                      BOOTLEG RED - 750ML
# 1       2020                MOMENT DE PLAISIR - 750ML
# 2       2020      S SMITH ORGANIC PEAR CIDER - 18.7OZ
# 3       2020            SCHLINK HAUS KABINETT - 750ML
# 4       2020           SANTORINI GAVALA WHITE - 750ML
# ...      ...                                      ...
# 307640  2020         DUTCHESS DE BOURGOGNE NR - 750ML
# 307641  2020                  HOEGAARDEN 4/6NR - 12OZ
# 307642  2020  DOMINION OAK BARREL STOUT 4/6 NR - 12OZ
# 307643  2020         SAM ADAMS SUMMER VARIETY 12PK NR
# 307644  2020                              WINE CREDIT
#
# [307645 rows x 2 columns]

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
# 307644  2020      9                                NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                           BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.loc[0, "YEAR"] = 2021
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2021      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
# 307644  2020      9                                NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                           BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2021      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
# 307644  2020      9                                NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                           BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.iat[1,1]
# Out:
# np.int64(1)

# %%
df.sort_values(["SUPPLIER"], ascending = False)
# Out:
#         YEAR  MONTH    SUPPLIER ITEM CODE  \
# 273180  2019     10  ZURENA LLC    300614
# 78184   2017      9  ZURENA LLC    300614
# 105338  2017     11  ZURENA LLC    300614
# 37920   2017      6  ZURENA LLC    300614
# 248231  2019      8  ZURENA LLC    300614
# ...      ...    ...         ...       ...
# 307336  2020      9         NaN       119
# 307473  2020      9         NaN         4
# 307600  2020      9         NaN       113
# 307613  2020      9         NaN         2
# 307644  2020      9         NaN        WC
#
#                                        ITEM DESCRIPTION     ITEM TYPE  \
# 273180  ZURENA LOVE ELIXIR CRAFT COCKTAIL MIXER - 750ML   NON-ALCOHOL
# 78184   ZURENA LOVE ELIXIR CRAFT COCKTAIL MIXER - 750ML   NON-ALCOHOL
# 105338  ZURENA LOVE ELIXIR CRAFT COCKTAIL MIXER - 750ML   NON-ALCOHOL
# 37920   ZURENA LOVE ELIXIR CRAFT COCKTAIL MIXER - 750ML   NON-ALCOHOL
# 248231  ZURENA LOVE ELIXIR CRAFT COCKTAIL MIXER - 750ML   NON-ALCOHOL
# ...

# %% [markdown]
# # filtering data

# %%
df.head()
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2021      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %%
df.tail()
# Out:
#         YEAR  MONTH                     SUPPLIER ITEM CODE  \
# 307640  2020      9                  LEGENDS LTD     99753
# 307641  2020      9           ANHEUSER BUSCH INC      9997
# 307642  2020      9  COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9      BOSTON BEER CORPORATION     99990
# 307644  2020      9                          NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 307640         DUTCHESS DE BOURGOGNE NR - 750ML      BEER          0.00
# 307641                  HOEGAARDEN 4/6NR - 12OZ      BEER         66.12
# 307642  DOMINION OAK BARREL STOUT 4/6 NR - 12OZ      BEER          2.25
# 307643         SAM ADAMS SUMMER VARIETY 12PK NR      BEER         20.50
# 307644                              WINE CREDIT       REF          0.00
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 307640               0.0             5.00
# 307641              37.0           240.75
# 307642               0.0             0.00
# ...

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2021      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
# 307644  2020      9                                NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                           BOOTLEG RED - 750ML      WINE          0.00
# ...
