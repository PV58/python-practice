# %% [markdown]
# # python data type

# %%
##PYTHON STRING
a = 'vilas'
b = 'patel'
print(a + b)
# Out:
# vilaspatel

# %%
#PYTHON INT
A = 1
B = 2
print(A+B)
# Out:
# 3

# %%
#FLOAT
a = 23.1
print(a)
# Out:
# 23.1

# %%
#boolean(always capital)
print(True)
print(False)
# Out:
# True
# False
